# %% [markdown]
# # Dataset cleaning

# %%
import pandas as pd 
import numpy as np

# %%
ds = pd.read_csv("book_data.csv")
ds.head()
# Out:
#                                         book_authors  ...                                          image_url
# 0                                    Suzanne Collins  ...  https://images.gr-assets.com/books/1447303603l...
# 1                         J.K. Rowling|Mary GrandPré  ...  https://images.gr-assets.com/books/1255614970l...
# 2                                         Harper Lee  ...  https://images.gr-assets.com/books/1361975680l...
# 3  Jane Austen|Anna Quindlen|Mrs. Oliphant|George...  ...  https://images.gr-assets.com/books/1320399351l...
# 4                                    Stephenie Meyer  ...  https://images.gr-assets.com/books/1361039443l...
#
# [5 rows x 12 columns]

# %%
ds.replace(to_replace='J.K. Rowling|Mary GrandPré', value='J.K. Rowling', inplace=True)
ds.head()
# Out:
#                                         book_authors  ...                                          image_url
# 0                                    Suzanne Collins  ...  https://images.gr-assets.com/books/1447303603l...
# 1                                       J.K. Rowling  ...  https://images.gr-assets.com/books/1255614970l...
# 2                                         Harper Lee  ...  https://images.gr-assets.com/books/1361975680l...
# 3  Jane Austen|Anna Quindlen|Mrs. Oliphant|George...  ...  https://images.gr-assets.com/books/1320399351l...
# 4                                    Stephenie Meyer  ...  https://images.gr-assets.com/books/1361039443l...
#
# [5 rows x 12 columns]

# %%
ds.drop(labels=3, axis=0, inplace=True)

# %%
#ds.iloc[5,:]
#ds['book_authors'][6]
ds.replace(to_replace='C.S. Lewis|Pauline Baynes', value='C.S. Lewis', inplace=True)
#ds.iloc[5,:]

# %%
#ds.iloc[6,:]
ds.drop(labels=7, axis=0, inplace=True)

# %%
#ds.iloc[7,:]
ds.drop(labels=9, axis=0, inplace=True)

# %%
ds.loc[10:20, ['book_authors', 'book_desc']]
# Out:
#                                          book_authors                                          book_desc
# 10                                         John Green  Despite the tumor-shrinking medical miracle th...
# 11                                      Douglas Adams  Seconds before the Earth is demolished to make...
# 12                                   Shel Silverstein  "Once there was a tree...and she loved a littl...
# 13  Emily Brontë|Richard J. Dunn|David Timson|Char...  You can find the redesigned cover of this edit...
# 14                                          Dan Brown  An ingenious code hidden in the works of Leona...
# 15                                      Arthur Golden  A literary sensation and runaway bestseller, t...
# 16          Lewis Carroll|John Tenniel|Martin Gardner  " I can't explain myself, I'm afraid, sir," sa...
# 17                      Oscar Wilde|Jeffrey Eugenides  ﻿Written in his distinctively dazzling manner,...
# ...

# %%
#ds['book_authors'][13]
ds.replace(to_replace='Emily Brontë|Richard J. Dunn|David Timson|Charlotte Brontë|Ruth Golding|Robert Heindel', value='Emily Brontë', inplace=True)

# %%
#ds['book_authors'][16]
ds.replace(to_replace='Lewis Carroll|John Tenniel|Martin Gardner', value='Lewis Carroll', inplace=True)

# %%
#ds['book_title'][17]
#ds['book_desc'][17]
#ds['book_authors'][17]
ds.replace(to_replace='Oscar Wilde|Jeffrey Eugenides', value='Oscar Wilde', inplace=True)

# %%
#ds['book_title'][18]
#ds['book_desc'][18]
#ds['book_authors'][18]
ds.replace(to_replace='Victor Hugo|Lee Fahnestock|Norman MacAfee', value='Victor Hugo', inplace=True)

# %%
#ds['book_title'][20]
#ds['book_desc'][20]
#ds['book_authors'][20]
ds.replace(to_replace='Charlotte Brontë|Michael Mason', value='Charlotte Brontë', inplace=True)

# %%
ds.loc[20:30, ['book_authors', 'book_title', 'book_desc']]
# Out:
#                                          book_authors  ...                                          book_desc
# 20                                   Charlotte Brontë  ...  Fiery love, shocking twists of fate, and tragi...
# 21  William Shakespeare|Barbara A. Mowat|Paul Wers...  ...  In Romeo and Juliet, Shakespeare creates a wor...
# 22                                    William Golding  ...  At the dawn of the next world war, a plane cra...
# 23           Paulo Coelho|Alan R. Clarke|Özdemir İnce  ...  Paulo Coelho's masterpiece tells the mystical ...
# 24                    Fyodor Dostoyevsky|David McDuff  ...  Raskolnikov, an impoverished student living in...
# 25                                   Orson Scott Card  ...  Andrew "Ender" Wiggin thinks he is playing com...
# 26                                    Stephen Chbosky  ...  The critically acclaimed debut novel from Step...
# ...

# %%
#ds['book_title'][21]
#ds['book_desc'][21]
#ds['book_authors'][21]
ds.replace(to_replace='William Shakespeare|Barbara A. Mowat|Paul Werstine', value='William Shakespeare', inplace=True)

# %%
#ds['book_title'][23]
#ds['book_desc'][23]
#ds['book_authors'][23]
ds.replace(to_replace='Paulo Coelho|Alan R. Clarke|Özdemir İnce', value='Paulo Coelho', inplace=True)

# %%
#ds['book_title'][24]
#ds['book_desc'][24]
#ds['book_authors'][24]
ds.replace(to_replace='Fyodor Dostoyevsky|David McDuff', value='Fyodor Dostoyevsky', inplace=True)

# %%
#ds['book_title'][27]
#ds['book_desc'][27]
#ds['book_authors'][27]
ds.replace(to_replace='Cassandra Clare|Franca Fritz|Heinrich Koop|Franka Fritz', value='Cassandra Clare', inplace=True)

# %%
#ds['book_title'][29]
#ds['book_desc'][29]
#ds['book_authors'][29]
ds.replace(to_replace='Alternate Cover Edition ISBN: 0743273567 (ISBN13: 9780743273565)A true classic of twentieth-century literature, this edition has been updated by Fitzgerald scholar James L.W. West III to include the author’s final revisions and features a note on the composition and text, a personal foreword by Fitzgerald’s granddaughter, Eleanor Lanahan—and a new introduction by two-time National Book Award winner Jesmyn Ward.The Great Gatsby, F. Scott Fitzgerald’s third book, stands as the supreme achievement of his career. First published in 1925, this quintessential novel of the Jazz Age has been acclaimed by generations of readers. The story of the mysteriously wealthy Jay Gatsby and his love for the beautiful Daisy Buchanan, of lavish parties on Long Island at a time when The New York Times noted “gin was the national drink and sex the national obsession,” it is an exquisitely crafted tale of America in the 1920s.', 
           value='A true classic of twentieth-century literature, this edition has been updated by Fitzgerald scholar James L.W. West III to include the author’s final revisions and features a note on the composition and text, a personal foreword by Fitzgerald’s granddaughter, Eleanor Lanahan—and a new introduction by two-time National Book Award winner Jesmyn Ward.The Great Gatsby, F. Scott Fitzgerald’s third book, stands as the supreme achievement of his career. First published in 1925, this quintessential novel of the Jazz Age has been acclaimed by generations of readers. The story of the mysteriously wealthy Jay Gatsby and his love for the beautiful Daisy Buchanan, of lavish parties on Long Island at a time when The New York Times noted “gin was the national drink and sex the national obsession,” it is an exquisitely crafted tale of America in the 1920s.', inplace=True)

# %%
ds['book_desc'][29]
# Out:
# 'A true classic of twentieth-century literature, this edition has been updated by Fitzgerald scholar James L.W. West III to include the author’s final revisions and features a note on the composition and text, a personal foreword by Fitzgerald’s granddaughter, Eleanor Lanahan—and a new introduction by two-time National Book Award winner Jesmyn Ward.The Great Gatsby, F. Scott Fitzgerald’s third book, stands as the supreme achievement of his career. First published in 1925, this quintessential novel of the Jazz Age has been acclaimed by generations of readers. The story of the mysteriously wealthy Jay Gatsby and his love for the beautiful Daisy Buchanan, of lavish parties on Long Island at a time when The New York Times noted “gin was the national drink and sex the national obsession,” it is an exquisitely crafted tale of America in the 1920s.'

# %%
ds.loc[30:40, ['book_authors', 'book_title', 'book_desc']]
# Out:
#                                          book_authors  ...                                          book_desc
# 30                                 Audrey Niffenegger  ...  A funny, often poignant tale of boy meets girl...
# 31           E.B. White|Garth Williams|Rosemary Wells  ...  This beloved book by E. B. White, author of St...
# 32                                    L.M. Montgomery  ...  As soon as Anne Shirley arrives at the snug wh...
# 33                                     John Steinbeck  ...  The compelling story of two outsiders striving...
# 34            Bram Stoker|Nina Auerbach|David J. Skal  ...  You can find an alternative cover edition for ...
# 35                                      Aldous Huxley  ...  Brave New World is a dystopian novel written i...
# 36             Gabriel García Márquez|Gregory Rabassa  ...  The brilliant, bestselling, landmark novel tha...
# ...

# %%
ds.replace(to_replace='E.B. White|Garth Williams|Rosemary Wells', value='E.B. White', inplace=True)
ds.replace(to_replace='Bram Stoker|Nina Auerbach|David J. Skal', value='Bram Stoker', inplace=True)
ds.replace(to_replace='Gabriel García Márquez|Gregory Rabassa', value='Gabriel García Márquez', inplace=True)

# %%
ds.replace(to_replace='Antoine de Saint-Exupéry|Richard Howard|Dom Marcos Barbosa|Melina Karakosta', value='Antoine de Saint-Exupéry', inplace=True)

# %%
ds.loc[40:50, ['book_authors', 'book_title', 'book_desc']]
# Out:
#                            book_authors  ...                                          book_desc
# 40                        J.D. Salinger  ...  The hero-narrator of The Catcher in the Rye is...
# 41                      Khaled Hosseini  ...  A Thousand Splendid Suns is a breathtaking sto...
# 42                    Madeleine L'Engle  ...  It was a dark and stormy night; Meg Murry, her...
# 43          Ray Bradbury|Alfredo Crespo  ...  Fahrenheit 451 ofrece la historia de un sombrí...
# 44                   George R.R. Martin  ...  Here is the first volume in George R. R. Marti...
# 45                         Rick Riordan  ...  Alternate cover for this ISBN can be found her...
# 46  Mark Twain|Guy Cardwell|John Seelye  ...  A nineteenth-century boy from a Mississippi Ri...
# 47                         Alice Sebold  ...  The Lovely Bones is the story of a family deva...
# 48                       Maurice Sendak  ...  One night Max puts on his wolf suit and makes ...
# ...

# %%
ds.replace(to_replace='Ray Bradbury|Alfredo Crespo', value='Ray Bradbury', inplace=True)
ds.replace(to_replace='Mark Twain|Guy Cardwell|John Seelye', value='Mark Twain', inplace=True)

# %%
ds.loc[50:60, ['book_authors', 'book_title', 'book_desc']]
# Out:
#                                          book_authors  ...                                          book_desc
# 50                                       J.K. Rowling  ...  Harry Potter's life is miserable. His parents ...
# 51                                        Yann Martel  ...  Life of Pi is a fantasy adventure novel by Yan...
# 52  Charles Dickens|Richard Maxwell|Hablot Knight ...  ...  \r\r\r\r\r\r\r\r\r\n'Liberty, equality, frater...
# 53                                        S.E. Hinton  ...  Librarian note: This record is for one of the ...
# 54                                         Sara Gruen  ...  Winner of the 2007 BookBrowse Award for Most P...
# 55                   Homer|Robert Fagles|Bernard Knox  ...  Sing to me of the man, Muse, the man of twists...
# 56                       Vladimir Nabokov|Craig Raine  ...  Humbert Humbert - scholar, aesthete and romant...
# ...

# %%
#ds['book_desc'][52]
ds.replace(to_replace="\r\r\r\r\r\r\r\r\r\n'Liberty, equality, fraternity, or death; -- the last, much the easiest to bestow, O Guillotine!\r\r\r\r\r\r\r\r\r\nAfter eighteen years as a political prisoner in the Bastille, the ageing Doctor Manette is finally released and reunited with his daughter in England. There the lives of two very different men, Charles Darnay, an exiled French aristocrat, and Sydney Carton, a disreputable but brilliant English lawyer, become enmeshed through their love for Lucie Manette. From the tranquil roads of London, they are drawn against their will to the vengeful, bloodstained streets of Paris at the height of the Reign of Terror, and they soon fall under the lethal shadow of La Guillotine.This edition uses the text as it appeared in its serial publication in 1859 to convey the full scope of Dickens's vision, and includes the original illustrations by H. K. Browne ('Phiz'). Richard Maxwell's introduction discusses the intricate interweaving of epic drama with personal tragedy.--back cover", 
           value="'Liberty, equality, fraternity, or death; -- the last, much the easiest to bestow, O Guillotine!' After eighteen years as a political prisoner in the Bastille, the ageing Doctor Manette is finally released and reunited with his daughter in England. There the lives of two very different men, Charles Darnay, an exiled French aristocrat, and Sydney Carton, a disreputable but brilliant English lawyer, become enmeshed through their love for Lucie Manette. From the tranquil roads of London, they are drawn against their will to the vengeful, bloodstained streets of Paris at the height of the Reign of Terror, and they soon fall under the lethal shadow of La Guillotine.This edition uses the text as it appeared in its serial publication in 1859 to convey the full scope of Dickens's vision, and includes the original illustrations by H. K. Browne ('Phiz'). Richard Maxwell's introduction discusses the intricate interweaving of epic drama with personal tragedy.", inplace=True)

# %%
#ds['book_authors'][52]
ds.replace(to_replace='Charles Dickens|Richard Maxwell|Hablot Knight Browne', value='Charles Dickens', inplace=True)

# %%
ds.replace(to_replace='Homer|Robert Fagles|Bernard Knox', value='Homer', inplace=True)
ds.replace(to_replace='Vladimir Nabokov|Craig Raine', value='Vladimir Nabokov', inplace=True)
ds.replace(to_replace='Mary Wollstonecraft Shelley|Percy Bysshe Shelley|Maurice Hindle', value='Mary Wollstonecraft Shelley', inplace=True)
#ds['book_authors'][59]

# %%
ds.loc[60:70, ['book_authors', 'book_title', 'book_desc']]
# Out:
#                      book_authors  ...                                          book_desc
# 60                Khaled Hosseini  ...   “It may be unfair, but what happens in a few ...
# 61                    Ken Follett  ...  Ken Follett is known worldwide as the master o...
# 62  Stephen King|Bernie Wrightson  ...  This is the way the world ends: with a nanosec...
# 63                     Lois Lowry  ...  Twelve-year-old Jonas lives in a seemingly ide...
# 64                 Richard  Adams  ...  Librarian's note: See alternate cover edition ...
# 65                Margaret Atwood  ...  Offred is a Handmaid in the Republic of Gilead...
# 66             Arthur Conan Doyle  ...  'It is an old maxim of mine that when you have...
# 67                   Jodi Picoult  ...  Anna is not sick, but she might as well be. By...
# 68                      Ken Kesey  ...  Like George Orwell and Philip Wylie, Ken Kesey...
# ...

# %%
ds.replace(to_replace='Stephen King|Bernie Wrightson', value='Stephen King', inplace=True)
ds.replace(to_replace='Sylvia Plath|Reinhard Kaiser', value='Sylvia Plath', inplace=True)

# %%
ds.loc[70:80, ['book_authors', 'book_title', 'book_desc']]
# Out:
#                  book_authors  ...                                          book_desc
# 70             Diana Gabaldon  ...  The year is 1945. Claire Randall, a former com...
# 71  Stieg Larsson|Reg Keeland  ...  A spellbinding amalgam of murder mystery, fami...
# 72          Daphne du Maurier  ...  Last night I dreamt I went to Manderley again ...
# 73               Betty  Smith  ...  The beloved American classic about a young gir...
# 74   Roald Dahl|Quentin Blake  ...  Matilda is a little girl who is far too good t...
# 75               Alice Walker  ...  The Color Purple is a classic. With over a mil...
# 76             J.R.R. Tolkien  ...  Alternate Cover Edition ISBN 0618260269 (copyr...
# 77          Louisa May Alcott  ...  Generations of readers young and old, male and...
# 78            Cormac McCarthy  ...  A searing, post apocalyptic novel destined to ...
# 79              Frank McCourt  ...  Imbued on every page with Frank McCourt's asto...
# ...

# %%
ds.replace(to_replace='Stieg Larsson|Reg Keeland', value='Stieg Larsson', inplace=True)
ds.replace(to_replace='Roald Dahl|Quentin Blake', value='Roald Dahl', inplace=True)

# %%
ds['book_desc'][76]
# Out:
# 'Alternate Cover Edition ISBN 0618260269 (copyright page ISBN is 0618346252 - different from back cover)One Ring to rule them all, One Ring to find them, One Ring to bring them all and in the darkeness bind themIn ancient times the Rings of Power were crafted by the Elven-smiths, and Sauron, The Dark Lord, forged the One Ring, filling it with his own power so that he could rule all others. But the One Ring was taken from him, and though he sought it throughout Middle-earth, it remained lost to him. After many ages it fell into the hands of Bilbo Baggins, as told in The Hobbit.In a sleepy village in the Shire, young Frodo Baggins finds himself faced with an immense task, as his elderly cousin Bilbo entrusts the Ring to his care. Frodo must leave his home and make a perilous journey across Middle-earth to the Cracks of Doom, there to destroy the Ring and foil the Dark Lord in his evil purpose.--back cover'

# %%
ds.replace(to_replace='Alternate Cover Edition ISBN 0618260269 (copyright page ISBN is 0618346252 - different from back cover)One Ring to rule them all, One Ring to find them, One Ring to bring them all and in the darkeness bind themIn ancient times the Rings of Power were crafted by the Elven-smiths, and Sauron, The Dark Lord, forged the One Ring, filling it with his own power so that he could rule all others. But the One Ring was taken from him, and though he sought it throughout Middle-earth, it remained lost to him. After many ages it fell into the hands of Bilbo Baggins, as told in The Hobbit.In a sleepy village in the Shire, young Frodo Baggins finds himself faced with an immense task, as his elderly cousin Bilbo entrusts the Ring to his care. Frodo must leave his home and make a perilous journey across Middle-earth to the Cracks of Doom, there to destroy the Ring and foil the Dark Lord in his evil purpose.--back cover', value='One Ring to rule them all, One Ring to find them, One Ring to bring them all and in the darkeness bind themIn ancient times the Rings of Power were crafted by the Elven-smiths, and Sauron, The Dark Lord, forged the One Ring, filling it with his own power so that he could rule all others. But the One Ring was taken from him, and though he sought it throughout Middle-earth, it remained lost to him. After many ages it fell into the hands of Bilbo Baggins, as told in The Hobbit.In a sleepy village in the Shire, young Frodo Baggins finds himself faced with an immense task, as his elderly cousin Bilbo entrusts the Ring to his care. Frodo must leave his home and make a perilous journey across Middle-earth to the Cracks of Doom, there to destroy the Ring and foil the Dark Lord in his evil purpose.', inplace=True)

# %%
ds.loc[150:200, ['book_authors', 'book_title', 'book_desc']]
# Out:
#                book_authors  ...                                          book_desc
# 150            Rick Riordan  ...  All year the half-bloods have been preparing f...
# 151         Nicholas Sparks  ...  Every April, when the wind blows from the sea ...
# 152  Gabriel García Márquez  ...  In their youth, Florentino Ariza and Fermina D...
# 153           Veronica Roth  ...  One choice can transform you—or it can destroy...
# 154      Colleen McCullough  ...  Powered by the dreams and struggles of three g...
# 155            J.K. Rowling  ...  The Dursleys were so mean and hideous that sum...
# 156               Dr. Seuss  ...  "The Grinch hated Christmas! The whole Christm...
# 157      Zora Neale Hurston  ...  Fair and long-legged, independent and articula...
# 158              Ian McEwan  ...  Ian McEwan’s symphonic novel of love and war, ...
# 159             Oscar Wilde  ...  Oscar Wilde's madcap farce about mistaken iden...
# ...

# %%
ds.replace(to_replace='Fyodor Dostoyevsky|Richard Pevear|Larissa Volokhonsky', value='Fyodor Dostoyevsky', inplace=True)
ds.replace(to_replace='Hermann Hesse|Hilda Rosner', value='Hermann Hesse', inplace=True)
ds.replace(to_replace='Ayn Rand|Leonard Peikoff', value='Ayn Rand', inplace=True)
ds.replace(to_replace='Miguel de Cervantes Saavedra|Roberto González Echevarría|John Rutherford|Ernani Ssó', value='Miguel de Cervantes Saavedra', inplace=True)
#ds['book_authors'][88]

# %%
ds.drop(labels=94, axis=0, inplace=True)

# %%
ds.replace(to_replace='A.A. Milne|Ernest H. Shepard', value='A.A. Milne', inplace=True)
ds.replace(to_replace='Leo Tolstoy|Richard Pevear|Larissa Volokhonsky', value='Leo Tolstoy', inplace=True)
ds.replace(to_replace='Herman Melville|Andrew Delbanco|Tom Quirk', value='Herman Melville', inplace=True)
ds.replace(to_replace='George Orwell|Erich Fromm', value='George Orwell', inplace=True)
ds.replace(to_replace='Charles Dickens|Marisa Sestino', value='Charles Dickens', inplace=True)
ds.replace(to_replace='Albert Camus|Matthew    Ward', value='Albert Camus', inplace=True)
ds.replace(to_replace="Mikhail Bulgakov|Katherine Tiernan O'Connor|Ellendea Proffer|Diana Burgin", value='Mikhail Bulgakov', inplace=True)
ds.replace(to_replace='Mitch Albom|Saulius Dagys', value='Mitch Albom', inplace=True)
ds.replace(to_replace='Carlos Ruiz Zafón|Lucia Graves', value='Carlos Ruiz Zafón', inplace=True)

# %%
ds.drop(labels=142, axis=0, inplace=True)

# %%
ds['book_authors'][123]
# Out:
# 'Milan Kundera|Michael Henry Heim|千野栄一'

# %%
ds.replace(to_replace='Milan Kundera|Michael Henry Heim|千野栄一', value='Milan Kundera', inplace=True)
ds.replace(to_replace='Franz Kafka|Stanley Corngold', value='Franz Kafka', inplace=True)
ds.replace(to_replace='Umberto Eco|William Weaver|Seán Barrett', value='Umberto Eco', inplace=True)
ds.replace(to_replace='Nathaniel Hawthorne|Thomas E. Connolly|Nina Baym', value='Nathaniel Hawthorne', inplace=True)
ds.replace(to_replace='Mario Puzo|Robert Thompson|Peter Bart', value='Mario Puzo', inplace=True)
ds.replace(to_replace='Leo Tolstoy|Aylmer Maude|Louise Maude', value='Leo Tolstoy', inplace=True)
ds.replace(to_replace='Laura Ingalls Wilder|Garth Williams', value='Laura Ingalls Wilder', inplace=True)
ds.replace(to_replace='Alan Moore|Dave Gibbons|John Higgins', value='Alan Moore', inplace=True)
ds.replace(to_replace='Dante Alighieri|Allen Mandelbaum|Eugenio Montale', value='Dante Alighieri', inplace=True)
ds.replace(to_replace='J.M. Barrie|Michael Hague', value='J.M. Barrie', inplace=True)
ds.replace(to_replace='Patrick Süskind|John E. Woods', value='Patrick Süskind', inplace=True)
ds.replace(to_replace='Erich Maria Remarque|A.W. Wheen', value='Erich Maria Remarque', inplace=True)
ds.replace(to_replace='Alexandre Dumas|Robin Buss', value='Alexandre Dumas', inplace=True)

# %%
ds.drop(labels=135, axis=0, inplace=True)

# %%
ds.drop(labels=180, axis=0, inplace=True)

# %%
#ds.replace(to_replace='', value='', inplace=True)
ds.replace(to_replace='Gabriel García Márquez|Edith Grossman', value='Gabriel García Márquez', inplace=True)
ds.replace(to_replace='L. Frank Baum|W.W. Denslow', value='L. Frank Baum', inplace=True)
ds.replace(to_replace='Margaret Wise Brown|Clement Hurd', value='Margaret Wise Brown', inplace=True)
ds.replace(to_replace='Thomas Hardy|Margaret R. Higonnet|Tim Dolin', value='Thomas Hardy', inplace=True)
ds.replace(to_replace='William Shakespeare|Barbara A. Mowat|Paul Werstine|Catherine Belsey', value='William Shakespeare', inplace=True)
ds.replace(to_replace='Terry Pratchett|Neil Gaiman', value='Terry Pratchett', inplace=True)
ds.replace(to_replace='Richard Bach|Russell Munson', value='Richard Bach', inplace=True)	
ds.replace(to_replace='Norton Juster|Jules Feiffer', value='Norton Juster', inplace=True)
ds.replace(to_replace='Gustave Flaubert|Malcolm Bowie|Margaret Mauldon|Mark Overstall', value='Gustave Flaubert', inplace=True)
ds.replace(to_replace='Charles Dickens|Philip Horne|George Cruikshank', value='Charles Dickens', inplace=True)
ds.replace(to_replace='Geoffrey Chaucer|Nevill Coghill', value='Geoffrey Chaucer', inplace=True)
ds.replace(to_replace='James Joyce|Morris L. Ernst|John M. Woolsey', value='James Joyce', inplace=True)

# %%
ds.drop(labels=199, axis=0, inplace=True)

# %%
ds.loc[350:400, ['book_authors', 'book_title', 'book_desc']]
# Out:
#                                           book_authors  ...                                          book_desc
# 350                           James Joyce|Seamus Deane  ...  The portrayal of Stephen Dedalus's Dublin chil...
# 351                                     Rainbow Rowell  ...  Two misfits.One extraordinary love.Eleanor... ...
# 352                           Alan Moore|David   Lloyd  ...  "Remember, remember the fifth of November..."A...
# 353                                Christopher Paolini  ...  Darkness falls…despair abounds…evil reigns…Era...
# 354                                       Rick Riordan  ...  Annabeth is terrified. Just when she's about t...
# 355                                       Stephen King  ...  Beginning with a short story appearing in The ...
# 356                                    Edgar Allan Poe  ...  Edgar Allan Poe remains the unsurpassed master...
# ...

# %%
from numpy import nan
indices = ds.index
for i in indices:
  if ds['book_desc'][i] is nan:
    ds.drop(labels=i, axis=0, inplace=True)

# %%
ds.drop(labels=260, axis=0, inplace=True)

# %%
#ds['book_desc'][255]
ds.replace(to_replace='[ \r\r\r\r\r\r\r\r\nBox Set\r\r\r\r\r\r\r\r\n | Book One | Book Two | Book Three ]Calvin and Hobbes is unquestionably one of the most popular comic strips of all time. The imaginative world of a boy and his real-only-to-him tiger was first syndicated in 1985 and appeared in more than 2,400 newspapers when Bill Watterson retired on January 1, 1996. The entire body of Calvin and Hobbes cartoons published in a truly noteworthy tribute to this singular cartoon in The Complete Calvin and Hobbes. Composed of three hardcover, four-color volumes in a sturdy slipcase, this New York Times best-selling edition includes all Calvin and Hobbes cartoons that ever appeared in syndication. This is the treasure that all Calvin and Hobbes fans seek.', value='Calvin and Hobbes is unquestionably one of the most popular comic strips of all time. The imaginative world of a boy and his real-only-to-him tiger was first syndicated in 1985 and appeared in more than 2,400 newspapers when Bill Watterson retired on January 1, 1996. The entire body of Calvin and Hobbes cartoons published in a truly noteworthy tribute to this singular cartoon in The Complete Calvin and Hobbes. Composed of three hardcover, four-color volumes in a sturdy slipcase, this New York Times best-selling edition includes all Calvin and Hobbes cartoons that ever appeared in syndication. This is the treasure that all Calvin and Hobbes fans seek.', inplace=True)

# %%
#ds['book_desc'][281]
ds.replace(to_replace="An alternative cover for this ISBN can be found hereSophie has the great misfortune of being the eldest of three daughters, destined to fail miserably should she ever leave home to seek her fate. But when she unwittingly attracts the ire of the Witch of the Waste, Sophie finds herself under a horrid spell that transforms her into an old lady. Her only chance at breaking it lies in the ever-moving castle in the hills: the Wizard Howl's castle. To untangle the enchantment, Sophie must handle the heartless Howl, strike a bargain with a fire demon, and meet the Witch of the Waste head-on. Along the way, she discovers that there's far more to Howl—and herself—than first meets the eye.", value="Sophie has the great misfortune of being the eldest of three daughters, destined to fail miserably should she ever leave home to seek her fate. But when she unwittingly attracts the ire of the Witch of the Waste, Sophie finds herself under a horrid spell that transforms her into an old lady. Her only chance at breaking it lies in the ever-moving castle in the hills: the Wizard Howl's castle. To untangle the enchantment, Sophie must handle the heartless Howl, strike a bargain with a fire demon, and meet the Witch of the Waste head-on. Along the way, she discovers that there's far more to Howl—and herself—than first meets the eye.", inplace=True)

# %%
ds['book_desc'][281]
# Out:
# "Sophie has the great misfortune of being the eldest of three daughters, destined to fail miserably should she ever leave home to seek her fate. But when she unwittingly attracts the ire of the Witch of the Waste, Sophie finds herself under a horrid spell that transforms her into an old lady. Her only chance at breaking it lies in the ever-moving castle in the hills: the Wizard Howl's castle. To untangle the enchantment, Sophie must handle the heartless Howl, strike a bargain with a fire demon, and meet the Witch of the Waste head-on. Along the way, she discovers that there's far more to Howl—and herself—than first meets the eye."

# %%
ds.replace(to_replace='Fyodor Dostoyevsky|Constance Garnett|Alan Myers|Joseph Frank|Anna Brailovsky', value='Fyodor Dostoyevsky', inplace=True)
#ds['book_authors'][279]

# %%
#ds['book_desc'][288]
#ds.replace(to_replace="", value="", inplace=True)
ds.replace(to_replace="Alternate cover edition: 9780439709101From internationally acclaimed storyteller Cornelia Funke, this bestselling, magical epic is now out in paperback!One cruel night, Meggie's father reads aloud from a book called INKHEART-- and an evil ruler escapes the boundaries of fiction and lands in their living room. Suddenly, Meggie is smack in the middle of the kind of adventure she has only read about in books. Meggie must learn to harness the magic that has conjured this nightmare. For only she can change the course of the story that has changed her life forever.This is INKHEART--a timeless tale about books, about imagination, about life. Dare to read it aloud.", value="From internationally acclaimed storyteller Cornelia Funke, this bestselling, magical epic is now out in paperback!One cruel night, Meggie's father reads aloud from a book called INKHEART-- and an evil ruler escapes the boundaries of fiction and lands in their living room. Suddenly, Meggie is smack in the middle of the kind of adventure she has only read about in books. Meggie must learn to harness the magic that has conjured this nightmare. For only she can change the course of the story that has changed her life forever.This is INKHEART--a timeless tale about books, about imagination, about life. Dare to read it aloud.", inplace=True)
ds.replace(to_replace="Cornelia Funke|Anthea Bell", value="Cornelia Funke", inplace=True)

# %%
#ds['book_desc'][335]
ds.replace(to_replace="\r\r\r\r\r\r\r\r\n'I felt something alive moving on my left leg ... when bending my Eyes downwards as much as I could. I perceived it to be a human Creature not six inches high'\r\r\r\r\r\r\r\r\nShipwrecked and cast adrift, Lemuel Gulliver wakes to find himself on Lilliput, an island inhabited by little people, whose height makes their quarrels over fashion and fame seem ridiculous. His subsequent encounters - with the crude giants of Brobdingnag, the philosophical Houyhnhnms and the brutish Yahoos - give Gulliver new, bitter insights into human behaviour. Swift's savage satire view mankind in a distorted hall of mirrors as a diminished, magnified and finally bestial species, presenting us with an uncompromising reflection of ourselves.This text, based on the first edition of 1726, reproduces all its original illustrations and includes an introduction by Robert Demaria, Jr, which discusses the ways Gulliver's Travels has been interpreted since its first publication.", value="'I felt something alive moving on my left leg ... when bending my Eyes downwards as much as I could. I perceived it to be a human Creature not six inches high' Shipwrecked and cast adrift, Lemuel Gulliver wakes to find himself on Lilliput, an island inhabited by little people, whose height makes their quarrels over fashion and fame seem ridiculous. His subsequent encounters - with the crude giants of Brobdingnag, the philosophical Houyhnhnms and the brutish Yahoos - give Gulliver new, bitter insights into human behaviour. Swift's savage satire view mankind in a distorted hall of mirrors as a diminished, magnified and finally bestial species, presenting us with an uncompromising reflection of ourselves.This text, based on the first edition of 1726, reproduces all its original illustrations and includes an introduction by Robert Demaria, Jr, which discusses the ways Gulliver's Travels has been interpreted since its first publication.", inplace=True)

# %%
ds.replace(to_replace="Jonathan Swift|Robert DeMaria Jr.", value="Jonathan Swift", inplace=True)

# %%
ds.drop(['book_edition',	'book_format',	'book_isbn',	'book_pages'], axis=1)
# Out:
#                                            book_authors  ...                                          image_url
# 0                                       Suzanne Collins  ...  https://images.gr-assets.com/books/1447303603l...
# 1                                          J.K. Rowling  ...  https://images.gr-assets.com/books/1255614970l...
# 2                                            Harper Lee  ...  https://images.gr-assets.com/books/1361975680l...
# 4                                       Stephenie Meyer  ...  https://images.gr-assets.com/books/1361039443l...
# 5                                          Markus Zusak  ...  https://images.gr-assets.com/books/1522157426l...
# ...                                                 ...  ...                                                ...
# 4872                                       Steve Kluger  ...  https://images.gr-assets.com/books/1442969941l...
# ...

# %%
ds.drop(['image_url'], axis=1)
# Out:
#                                            book_authors  ...                                             genres
# 0                                       Suzanne Collins  ...  Young Adult|Fiction|Science Fiction|Dystopia|F...
# 1                                          J.K. Rowling  ...                        Fantasy|Young Adult|Fiction
# 2                                            Harper Lee  ...  Classics|Fiction|Historical|Historical Fiction...
# 4                                       Stephenie Meyer  ...  Young Adult|Fantasy|Romance|Paranormal|Vampire...
# 5                                          Markus Zusak  ...  Historical|Historical Fiction|Fiction|Young Adult
# ...                                                 ...  ...                                                ...
# 4872                                       Steve Kluger  ...  Young Adult|Fiction|Romance|Lgbt|Contemporary|...
# ...

# %%
ds = ds.drop(['book_edition',	'book_format',	'book_isbn',	'book_pages', 'image_url'], axis=1)

# %%
ds.head(10)
# Out:
#          book_authors  ...                                             genres
# 0     Suzanne Collins  ...  Young Adult|Fiction|Science Fiction|Dystopia|F...
# 1        J.K. Rowling  ...                        Fantasy|Young Adult|Fiction
# 2          Harper Lee  ...  Classics|Fiction|Historical|Historical Fiction...
# 4     Stephenie Meyer  ...  Young Adult|Fantasy|Romance|Paranormal|Vampire...
# 5        Markus Zusak  ...  Historical|Historical Fiction|Fiction|Young Adult
# 6          C.S. Lewis  ...     Fantasy|Classics|Fiction|Young Adult|Childrens
# 8   Margaret Mitchell  ...  Classics|Historical|Historical Fiction|Fiction...
# 10         John Green  ...           Young Adult|Fiction|Romance|Contemporary
# 11      Douglas Adams  ...     Science Fiction|Fiction|Humor|Fantasy|Classics
# 12   Shel Silverstein  ...  Childrens|Childrens|Picture Books|Classics|Fic...
#
# [10 rows x 7 columns]

# %%
cols = ds.columns.tolist()

# %%
cols
# Out:
# ['book_authors',
#  'book_desc',
#  'book_rating',
#  'book_rating_count',
#  'book_review_count',
#  'book_title',
#  'genres']

# %%
cols = ['book_authors', 'book_title', 'book_desc', 'book_rating', 'book_rating_count', 'book_review_count', 'genres']

# %%
cols
# Out:
# ['book_authors',
#  'book_title',
#  'book_desc',
#  'book_rating',
#  'book_rating_count',
#  'book_review_count',
#  'genres']

# %%
ds = ds[cols]

# %%
ds
# Out:
#           book_authors  ...                                             genres
# 0      Suzanne Collins  ...  Young Adult|Fiction|Science Fiction|Dystopia|F...
# 1         J.K. Rowling  ...                        Fantasy|Young Adult|Fiction
# 2           Harper Lee  ...  Classics|Fiction|Historical|Historical Fiction...
# 4      Stephenie Meyer  ...  Young Adult|Fantasy|Romance|Paranormal|Vampire...
# 5         Markus Zusak  ...  Historical|Historical Fiction|Fiction|Young Adult
# ...                ...  ...                                                ...
# 4872      Steve Kluger  ...  Young Adult|Fiction|Romance|Lgbt|Contemporary|...
# 4873  Kimberly Derting  ...  Mystery|Romance|Fantasy|Young Adult|Fantasy|Su...
# 4874      Eva Ibbotson  ...  Historical|Historical Fiction|Young Adult|Chil...
# 4875        Fábio Moon  ...  Sequential Art|Graphic Novels|Sequential Art|C...
# 4876      Peter Singer  ...                   Philosophy|Nonfiction|Animals|Fo
#
# [4847 rows x 7 columns]

# %%
ds['book_authors'][4875]
# Out:
# 'Fábio Moon|Gabriel Bá|Craig Thompson|Dave Stewart|Sean Konot'

# %%
ds.replace(to_replace='Fábio Moon|Gabriel Bá|Craig Thompson|Dave Stewart|Sean Konot', value='Fábio Moon', inplace=True)

# %%
ds['book_desc'][4876]
# Out:
# 'The Book That Started A Revolution. Since its original publication in 1975, this groundbreaking work has awakened millions of concerned men and women to the shocking abuse of animals everywhere -- inspiring a worldwide movement to eliminate much of the cruel and unnecessary laboratory animal experimentation of years past. In this newly revised and expanded edition, author Peter Singer exposes the chilling realities of today\'s "factory forms" and product-testing procedures -- offering sound, humane solutions to what has become a profound environmental and social as well as moral issue. An important and persuasive appeal to conscience, fairness, decency and justice, Animal Liberation is essential reading for the supporter and the skeptic alike.'

# %%
ds.replace(to_replace='\r\r\r\r\r\r\nThe Book That Started A Revolution\r\r\r\r\r\r\nSince its original publication in 1975, this groundbreaking work has awakened millions of concerned men and women to the shocking abuse of animals everywhere -- inspiring a worldwide movement to eliminate much of the cruel and unnecessary laboratory animal experimentation of years past. In this newly revised and expanded edition, author Peter Singer exposes the chilling realities of today\'s "factory forms" and product-testing procedures -- offering sound, humane solutions to what has become a profound environmental and social as well as moral issue. An important and persuasive appeal to conscience, fairness, decency and justice, Animal Liberation is essential reading for the supporter and the skeptic alike.', value='The Book That Started A Revolution. Since its original publication in 1975, this groundbreaking work has awakened millions of concerned men and women to the shocking abuse of animals everywhere -- inspiring a worldwide movement to eliminate much of the cruel and unnecessary laboratory animal experimentation of years past. In this newly revised and expanded edition, author Peter Singer exposes the chilling realities of today\'s "factory forms" and product-testing procedures -- offering sound, humane solutions to what has become a profound environmental and social as well as moral issue. An important and persuasive appeal to conscience, fairness, decency and justice, Animal Liberation is essential reading for the supporter and the skeptic alike.', inplace=True)

# %%
ds.loc[50:100, ['book_authors', 'book_title', 'book_desc']]
# Out:
#                      book_authors  ...                                          book_desc
# 50                   J.K. Rowling  ...  Harry Potter's life is miserable. His parents ...
# 51                    Yann Martel  ...  Life of Pi is a fantasy adventure novel by Yan...
# 52                Charles Dickens  ...  'Liberty, equality, fraternity, or death; -- t...
# 53                    S.E. Hinton  ...  Librarian note: This record is for one of the ...
# 54                     Sara Gruen  ...  Winner of the 2007 BookBrowse Award for Most P...
# 55                          Homer  ...  Sing to me of the man, Muse, the man of twists...
# 56               Vladimir Nabokov  ...  Humbert Humbert - scholar, aesthete and romant...
# 57                  Kurt Vonnegut  ...  Selected by the Modern Library as one of the 1...
# 58                  Joseph Heller  ...  The novel is set during World War II, from 194...
# ...

# %%
ds['book_desc'][52]
# Out:
# "'Liberty, equality, fraternity, or death; -- the last, much the easiest to bestow, O Guillotine!' After eighteen years as a political prisoner in the Bastille, the ageing Doctor Manette is finally released and reunited with his daughter in England. There the lives of two very different men, Charles Darnay, an exiled French aristocrat, and Sydney Carton, a disreputable but brilliant English lawyer, become enmeshed through their love for Lucie Manette. From the tranquil roads of London, they are drawn against their will to the vengeful, bloodstained streets of Paris at the height of the Reign of Terror, and they soon fall under the lethal shadow of La Guillotine.This edition uses the text as it appeared in its serial publication in 1859 to convey the full scope of Dickens's vision, and includes the original illustrations by H. K. Browne ('Phiz'). Richard Maxwell's introduction discusses the intricate interweaving of epic drama with personal tragedy."

# %%
ds.replace(to_replace="\r\r\r\r\r\r\r\r\r\n'Liberty, equality, fraternity, or death; -- the last, much the easiest to bestow, O Guillotine!'\r\r\r\r\r\r\r\r\r\nAfter eighteen years as a political prisoner in the Bastille, the ageing Doctor Manette is finally released and reunited with his daughter in England. There the lives of two very different men, Charles Darnay, an exiled French aristocrat, and Sydney Carton, a disreputable but brilliant English lawyer, become enmeshed through their love for Lucie Manette. From the tranquil roads of London, they are drawn against their will to the vengeful, bloodstained streets of Paris at the height of the Reign of Terror, and they soon fall under the lethal shadow of La Guillotine.This edition uses the text as it appeared in its serial publication in 1859 to convey the full scope of Dickens's vision, and includes the original illustrations by H. K. Browne ('Phiz'). Richard Maxwell's introduction discusses the intricate interweaving of epic drama with personal tragedy.--back cover", value="'Liberty, equality, fraternity, or death; -- the last, much the easiest to bestow, O Guillotine!' After eighteen years as a political prisoner in the Bastille, the ageing Doctor Manette is finally released and reunited with his daughter in England. There the lives of two very different men, Charles Darnay, an exiled French aristocrat, and Sydney Carton, a disreputable but brilliant English lawyer, become enmeshed through their love for Lucie Manette. From the tranquil roads of London, they are drawn against their will to the vengeful, bloodstained streets of Paris at the height of the Reign of Terror, and they soon fall under the lethal shadow of La Guillotine.This edition uses the text as it appeared in its serial publication in 1859 to convey the full scope of Dickens's vision, and includes the original illustrations by H. K. Browne ('Phiz'). Richard Maxwell's introduction discusses the intricate interweaving of epic drama with personal tragedy.", inplace=True)

# %%
ds.to_csv(r'new_book_data.csv', index = False, header=True)

# %%
nbds = pd.read_csv('new_book_data.csv')
nbds
# Out:
#           book_authors  ...                                             genres
# 0      Suzanne Collins  ...  Young Adult|Fiction|Science Fiction|Dystopia|F...
# 1         J.K. Rowling  ...                        Fantasy|Young Adult|Fiction
# 2           Harper Lee  ...  Classics|Fiction|Historical|Historical Fiction...
# 3      Stephenie Meyer  ...  Young Adult|Fantasy|Romance|Paranormal|Vampire...
# 4         Markus Zusak  ...  Historical|Historical Fiction|Fiction|Young Adult
# ...                ...  ...                                                ...
# 4842      Steve Kluger  ...  Young Adult|Fiction|Romance|Lgbt|Contemporary|...
# 4843  Kimberly Derting  ...  Mystery|Romance|Fantasy|Young Adult|Fantasy|Su...
# 4844      Eva Ibbotson  ...  Historical|Historical Fiction|Young Adult|Chil...
# 4845        Fábio Moon  ...  Sequential Art|Graphic Novels|Sequential Art|C...
# 4846      Peter Singer  ...                   Philosophy|Nonfiction|Animals|Fo
#
# [4847 rows x 7 columns]
